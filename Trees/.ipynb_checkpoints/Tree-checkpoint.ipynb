# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.right = None
        self.left = None

# %%
class BST:
    def __init__(self):
        self.root = None

# %%
tree = BST()

# %%
print(tree.root)
# Out:
# None
