# %%
class Node:
    def __init__(self,val):
        self.val = val
        self.next = None

# %%
class Queue:
    def __init__(self):
        self.first = None
        self.last = None
        self.size = 0


    def enqueue(self,val):

        temp = Node(val)
        if self.first is None:
            self.first = temp
            self.last = temp
         
        else:
            temp.next = self.last
            self.last = temp 
            
        
        
        
        self.size += 1
    def dequeue(self):
      if self.size == 0:
          return "queue empty"

      temp = self.first 

      if self.size == 1:
        self.fist = None
        self.last = None
    
      else:
          
          self.first = self.first.next
          temp.next = None 
      self.size -= 1
